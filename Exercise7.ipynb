# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import nltk
import seaborn as sns
import re
import os, types

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import roc_auc_score, roc_curve, confusion_matrix, precision_score, recall_score, accuracy_score, balanced_accuracy_score, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download("punkt")
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
splits = {'train': 'unique_train_dataset.csv', 'validation': 'unique_validation_dataset.csv', 'test': 'unique_test_dataset.csv'}

# %%
df = pd.read_csv("hf://datasets/mapsoriano/2016_2022_hate_speech_filipino/" + splits["train"])

dt = pd.read_csv("hf://datasets/mapsoriano/2016_2022_hate_speech_filipino/" + splits["validation"])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
df.head()
# Out:
#                                                 text  label
# 0  Presidential candidate Mar Roxas implies that ...      1
# 1  Parang may mali na sumunod ang patalastas ng N...      1
# 2                    Bet ko. Pula Ang Kulay Ng Posas      1
# 3                               [USERNAME] kakampink      0
# 4  Bakit parang tahimik ang mga PINK about Doc Wi...      1

# %%
dt.head()
# Out:
#                                                 text  label
# 0  VinTee [USERNAME] [USERNAME] and [USERNAME] Ka...      1
# 1  binay's sidekicks were employees of makati cit...      1
# 2   This is expected as we use different methodol...      0
# 3   Ang tanga tanga talaga ni Nancy Binay eh. Tskkk.      1
# 4  Binay giving away bracelets after every selfie...      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21773 entries, 0 to 21772
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    21773 non-null  object
#  1   label   21773 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 340.3+ KB

# %%
df.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# Assuming 'label' is the column containing the labels
df['label'].value_counts().plot(kind='bar')
plt.title('Distribution of Labels in Training Dataset')
plt.xlabel('Label')
plt.ylabel('Count')
plt.show()

# %%
stopwords_set = set()

# Open the text file in read mode
with open('stopwords-tl.txt', 'r', encoding='utf-8') as file:
    for line in file:
        # Strip leading/trailing whitespace (including newline characters)
        word = line.strip()
        # Add the word to the set
        stopwords_set.add(word)

# Print the resulting set
print(stopwords_set)
# Out:
# {'isang', 'old', 'via', 'group', 's', 'jp', 'nr', 'years', 'according', 'from', 'su', 'relatively', 'round', 'thoughh', 'up', 'changes', 'opposite', 'brief', 'click', 'gy', 'thered', "what've", 'obtain', 'specifically', 'taking', 'shall', 'containing', 'fo', 'fr', "t's", 'p', 'ordering', 'niya', 'np', "i'd", 'obviously', 'whomever', 'mx', 'don', 'therell', "why's", 'sixty', 'front', "when'd", 'downs', 'am', 'niyang', 'marapat', 'got', 'how', 'began', 'was', 'mill', 'eh', 'beside', 'ae', 'asking', "aren't", 'before', 'couldnt', 'detail', 'dahil', 'eighty', 'lc', 'gm', "would've", 'pagkakaroon', 'they', 'bb', 'wasnt', 'py', 'pages', 'hereupon', 'stop', 'cs', 'ending', 'side', 'lb', 'appropriate', 'auth', 'second', 'beginnings', 'bakit', 'rw', 'interests', 'ay', 'presented', 'call', 'uz', "who'd", 'que', 'lv', 'beginning', 'otherwise', 'newer', 'plus', 'poorly', 'sy', 'accordance', 'nobody', 'ilalim', 'gusto', 'everywhere', 'gr', 'unfortunately', 'knows', 'is', 'going', 'o', 'sufficiently', 'respectively', 'made', 'so', 'too', 'someone', 'upon', 'thence', 'pointed', 'were', 'get', 'nor', 'first', 'fify', 'amongst', 'thru', 'homepage', 'ten', 'backed', 'hither', 'contains', 'important', 'gayunman', 'concerning', 'c', 'doesn', 'tg', 'iq', 'more', "there'd", 'ginagawa', "didn't", 'opening', 'opens', 'value', "c'mon", 'saw', 'doing', 'needing', 'th', 'provided', 'tell', 'cause', 'noon', 'if', 'these', 'ht', 'gp', 'see', 'nais', 'b', 'points', 'tk', 'ff', 'minus', 'ua', "daren't", 'willing', 'twelve', 'puts', 'looks', "could've", 'bo', 'html', "they're", 'ring', 'hi', 'alone', 'herse”', 'goes', 'work', 'hid', 'ec', 'ran', 'good', "what'd", 'youngest', 'es', 'fm', "shan't", "isn't", 'na', 'kaysa', 'ninety', 'darent', "'ve", 'tries', 'unto', 'kailangan', 'cg', 'gl', 'w', 'pt', 'theyd', 'associated', 'ex', 'text', 'giving', 'normally', 'theyll', 'edu', 'provides', 'among', 'ii', 'weren', 'ways', 'fully', 'web', 'shouldnt', 'members', 'pa', 'like', 'tw', 'most', 'lr', 'merely', 'two', 'our', "there's", 'wouldn', 'un', 'same', 'least', 'kung', 'what', 'therein', 'three', 'az', 'none', 'bill', 'such', 'bf', 'fewer', 'older', 'saying', 'exactly', 'ml', 'ch', 'full', "who's", 'just', 'wouldnt', 'kanino', 'vc', 'ngayon', 'nevertheless', 'could', 'ah', 'date', 'shell', "i've", 'gn', 'isa', 'kanila', 'anyway', 'furthermore', 'seemed', 'ne', 'eight', 'tulad', 'mg', 'thatve', 'isn', 'despite', 'maynt', 'mv', 'nz', 'zm', 'either', 'finds', 'longest', 'my', 'on', 'five', 'try', 'bz', 'truly', 'free', 'afterwards', 'fifty', 'moreover', "'tis", 'act', 'gumawa', 'kz', 'said', 'fix', 'thirty', "there'll", 'adj', 'showns', 'regards', 'aming', 'ga', 'last', 'few', 'mm', 'furthering', 'overall', 'into', 'namely', 'maaari', 'possibly', 'everything', 'refs', 'bababa', 'differ', 'consider', 'ee', 'amidst', 'similar', 'unlike', 'need', 'affects', 'al', 'computer', 'ro', 'keeps', 'k', 'therere', 'obtained', 'wants', 'bawat', 'face', 'instead', 'thin', 'gets', 'nos', 'tz', 'likely', 'parting', 'dapat', 'even', 'secondly', 'research', 'vs', 'part', 'x', 'kh', 'whether', 'fill', 'problem', "when's", 'fi', 'ive', 'have', 'describe', 'll', 'website', 'v', 'one', 'iyon', 'seen', 'worked', 'id', 'considering', 'ilan', "they'd", 'vu', 'able', 'neednt', 'beforehand', 'knew', 't', 'except', 'in', "why'll", 'do', 'as', 'must', 'affected', 'l', 'turns', 'wish', 'gives', 'ka', 'say', 'gg', 'itd', 'mc', 'sl', 'those', 'kaya', 'yourselves', 'kind', 'tj', 'year', 'whereby', "hadn't", 'sorry', '10', 'pg', 'webpage', 'ye', 'kn', 'significant', 'across', 'sec', 'therefore', 'aint', "that've", 'described', 'thereupon', 'added', 'whenever', 'owing', 'example', 'yourself', 'd', 'hasn', 'grouping', 'nilang', 'siya', 'bi', 'ito', 'related', 'open', 'fk', "i'll", 'ibaba', 'alongside', 'yours', 'every', 'anybody', 'placed', 'know', 'sh', 'forward', 'sometime', 'whatever', 'inner', 'only', 'this', 'line', 'now', 'used', 'past', 'i', 'kept', 'above', 'inside', 'why', 'anything', 'back', ' ...

# %%
import re
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

nltk.download("stopwords")
# nltk.download('punkt')

def clean_message(message):
    message = re.sub("[^A-Za-z]", " ", message)
    message = message.lower()
    message = message.split()
    stemmer = PorterStemmer()
    message = [stemmer.stem(word) for word in message if word not in stopwords_set] #5
    message = " ".join(message)
    return message
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
messages = []
for i in range(0, len(df)):
    message = clean_message(df.text[i])
    messages.append(message)
df = df.drop(["text"],axis=1)
df['messages'] = messages
df.head()
# Out:
#    label                                           messages
# 0      1  presidenti candid mar roxa impli govt liabl la...
# 1      1  parang mali sumunod patalasta nescaf coffe bla...
# 2      1                                bet pula kulay posa
# 3      0                                  usernam kakampink
# 4      1   parang tahimik pink doc willi ong reaction paper

# %%
messages = []
for i in range(0, len(dt)):
    message = clean_message(dt.text[i])
    messages.append(message)
dt = dt.drop(["text"],axis=1)
dt['messages'] = messages
dt.head()
# Out:
#    label                                           messages
# 0      1  vinte usernam usernam usernam di aasenso pina ...
# 1      1  binay sidekick employe makati citi hall deposi...
# 2      0  expect methodolog puls asia survey entir popul...
# 3      1               tanga tanga talaga nanci binay tskkk
# 4      0                       binay bracelet selfi usernam

# %%
x = df["messages"].values
y = df["label"].values
x_test = dt["messages"].values
y_test = dt["label"].values

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect1 = CountVectorizer(stop_words='english',max_df=0.7)

#fitting train data and then transforming it to count matrix#fitting
X_train_transformed = vect1.fit_transform(x)
X_test_transformed = vect1.transform(x_test)

# %%
# importing naive bayes algorithm
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()

#fitting the model into train data
nb.fit(X_train_transformed, y)

#predicting the model on train and test data
y_pred_test = nb.predict(X_test_transformed)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print(accuracy_score(y_test,y_pred_test)*100)

accuracy = accuracy_score(y_test, y_pred_test)
print(f"Accuracy: {accuracy * 100:.2f}%")


precision = precision_score(y_test, y_pred_test)
print(f"Precision: {precision:.2f}")


sensitivity = recall_score(y_test, y_pred_test)
print(f"Sensitivity (Recall): {sensitivity:.2f}")


f1 = f1_score(y_test, y_pred_test)
print(f"F1 Score: {f1:.2f}")


from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred_test)
print(cm)
# Out:
# 83.89285714285715
# Accuracy: 83.89%
# Precision: 0.81
# Sensitivity (Recall): 0.89
# F1 Score: 0.85
# [[1086  299]
#  [ 152 1263]]

# %%
new_text = pd.Series('Baliw, tanong mo sa mama mo.')
new_text_transform = vect1.transform(new_text)
print(" The message is a" ,nb.predict(new_text_transform))
# Out:
#  The message is a [1]
